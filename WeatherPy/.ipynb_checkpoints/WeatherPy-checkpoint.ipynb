# %% [markdown]
# # WeatherPy
# ----
#
# #### Analysis
# 1) Lat vs Temp: although it 'seems' at first glance that the northern hemisphere is colder than the southern hemisphere, in fact, there are less cities plotted within the southern hemisphere, and therefore the data is not represented to the same degree for '-40 to -80' lat vs. '40 to 80' lat, where there is more representation of cities.
# 2) Lat vs Humidity: a cluster seems to be formed around 40-60 lat, but this could be due to the sample of data produced. A way to mitigate this would have been to split the latitudes & longitudes into 4 quadrants, and then randomly assigning them together to ensure a fair representation around the globe.
# 3) Lat vs Cloudiness: cloudiness looks to be rounded with most citings of 20%, 40%, 75%, 90% and 100%.
# 4) Lat & wind speed: do not look correlated, rare for windspeed to be over 20 mph.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint 

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/jennybersinic/opt/anaconda3/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/jennybersinic/opt/anaconda3/lib/python3.7/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

#Check URL
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=

# %%
# Set up lists to hold reponse info
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# %%
# Loop through cities, make weather API requests, append desired results (with print log of city name, number)
record_count = 1
set_count = 1

for i, city in enumerate (cities):
    time.sleep(1)
    if (i%50==0 and i>=50):
        set_count +=1
        record_count = 0
    print (f"Processing Record {record_count} of Set {set_count} | {city} \n")
    print (f"{query_url}{city}\n")
    record_count += 1
    
    response = requests.get(query_url + city).json()
    try:
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
    except:
        print(f"City Not Found, Skipped.")
        pass
# Out:
# Processing Record 1 of Set 1 | rikitea
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=rikitea
#
# Processing Record 2 of Set 1 | beringovskiy
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=beringovskiy
#
# Processing Record 3 of Set 1 | albany
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=albany
#
# Processing Record 4 of Set 1 | la tuque
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=la tuque
#
# Processing Record 5 of Set 1 | praia da vitoria
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=praia da vitoria
#
# Processing Record 6 of Set 1 | beloha
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=beloha
#
# Processing Record 7 of Set 1 | hilo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=hilo
#
# Processing Record 8 of Set 1 | ushuaia
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=ushuaia
#
# Processing Record 9 of Set 1 | salvador
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=salvador
#
# Processing Record 10 of Set 1 | vulturu
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=vulturu
#
# Processing Record 11 of Set 1 | glendive
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=glendive
#
# Processing Record 12 of Set 1 | pangnirtung
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=pangnirtung
#
# Processing Record 13 of Set 1 | klaksvik
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=klaksvik
#
# Processing Record 14 of Set 1 | ancud
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=ancud
#
# Processing Record 15 of Set 1 | hithadhoo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=hithadhoo
#
# Processing Record 16 of Set 1 | magnolia
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=magnolia
#
# Processing Record 17 of Set 1 | cape town
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=cape town
#
# Processing Record 18 of Set 1 | emerald
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=emerald
#
# Processing Record 19 of Set 1 | bethel
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=bethel
#
# Processing Record 20 of Set 1 | sept-iles
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=sept-iles
#
# Processing Record 21 of Set 1 | praxedis guerrero
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=praxedis guerrero
#
# Processing Record 22 of Set 1 | inderborskiy
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=inderborskiy
#
# City Not Found, Skipped.
# Processing Record 23 of Set 1 | sabang
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=sabang
#
# Processing Record 24 of Set 1 | hornepayne
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=hornepayne
#
# Processing Record 25 of Set 1 | mount isa
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=mount isa
#
# Processing Record 26 of Set 1 | airai
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=airai
#
# Processing Record 27 of Set 1 | sao filipe
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=sao filipe
#
# Processing Record 28 of Set 1 | hobart
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=hobart
#
# Processing Record 29 of Set 1 | edeia
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=edeia
#
# Processing Record 30 of Set 1 | barrow
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=barrow
#
# Processing Record 31 of Set 1 | hami
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=hami
#
# Processing Record 32 of Set 1 | illoqqortoormiut
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=illoqqortoormiut
#
# City Not Found, Skipped.
# Processing Record 33 of Set 1 | busselton
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=busselton
#
# Processing Record 34 of Set 1 | tromso
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tromso
#
# Processing Record 35 of Set 1 | shenkursk
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=shenkursk
#
# Processing Record 36 of Set 1 | boa vista
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=boa vista
#
# Processing Record 37 of Set 1 | saint-augustin
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=saint-augustin
#
# Processing Record 38 of Set 1 | katsuura
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=katsuura
#
# Processing Record 39 of Set 1 | nikolskoye
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=nikolskoye
#
# Processing Record 40 of Set 1 | torbay
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=torbay
#
# Processing Record 41 of Set 1 | narsaq
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=narsaq
#
# Processing Record 42 of Set 1 | ucluelet
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=ucluelet
#
# Processing Record 43 of Set 1 | sinegorye
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=sinegorye
#
# Processing Record 44 of Set 1 | isangel
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=isangel
#
# Processing Record 45 of Set 1 | tessalit
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tessalit
#
# Processing Record 46 of Set 1 | nantucket
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=nantucket
#
# Processing Record 47 of Set 1 | dikson
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=dikson
#
# Processing Record 48 of Set 1 | bluff
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=bluff
#
# Processing Record 49 of Set 1 | kapaa
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kapaa
#
# Processing Record 50 of Set 1 | san patricio
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=san patricio
#
# Processing Record 0 of Set 2 | kassala
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kassala
#
# Processing Record 1 of Set 2 | taolanaro
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=taolanaro
#
# City Not Found, Skipped.
# Processing Record 2 of Set 2 | cidreira
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=cidreira
#
# Processing Record 3 of Set 2 | cherskiy
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=cherskiy
#
# Processing Record 4 of Set 2 | tashla
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tashla
#
# Processing Record 5 of Set 2 | pontes e lacerda
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=pontes e lacerda
#
# Processing Record 6 of Set 2 | atuona
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=atuona
#
# Processing Record 7 of Set 2 | faya
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=faya
#
# Processing Record 8 of Set 2 | new norfolk
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=new norfolk
#
# Processing Record 9 of Set 2 | ust-kan
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=ust-kan
#
# Processing Record 10 of Set 2 | steamboat springs
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=steamboat springs
#
# Processing Record 11 of Set 2 | georgetown
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=georgetown
#
# Processing Record 12 of Set 2 | bambous virieux
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=bambous virieux
#
# Processing Record 13 of Set 2 | butaritari
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=butaritari
#
# Processing Record 14 of Set 2 | punta arenas
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=punta arenas
#
# Processing Record 15 of Set 2 | kabalo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kabalo
#
# Processing Record 16 of Set 2 | huarmey
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=huarmey
#
# Processing Record 17 of Set 2 | mataura
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=mataura
#
# Processing Record 18 of Set 2 | quatre cocos
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=quatre cocos
#
# Processing Record 19 of Set 2 | kommunisticheskiy
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kommunisticheskiy
#
# Processing Record 20 of Set 2 | hasaki
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=hasaki
#
# Processing Record 21 of Set 2 | san carlos de bariloche
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=san carlos de bariloche
#
# Processing Record 22 of Set 2 | bourail
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=bourail
#
# Processing Record 23 of Set 2 | saint-philippe
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=saint-philippe
#
# Processing Record 24 of Set 2 | hualmay
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=hualmay
#
# Processing Record 25 of Set 2 | karla
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=karla
#
# Processing Record 26 of Set 2 | college
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=college
#
# Processing Record 27 of Set 2 | lavrentiya
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=lavrentiya
#
# Processing Record 28 of Set 2 | toyooka
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=toyooka
#
# Processing Record 29 of Set 2 | vila praia de ancora
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=vila praia de ancora
#
# Processing Record 30 of Set 2 | vaini
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=vaini
#
# Processing Record 31 of Set 2 | norman wells
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=norman wells
#
# Processing Record 32 of Set 2 | antofagasta
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=antofagasta
#
# Processing Record 33 of Set 2 | port elizabeth
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=port elizabeth
#
# Processing Record 34 of Set 2 | mehamn
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=mehamn
#
# Processing Record 35 of Set 2 | jiddah
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=jiddah
#
# City Not Found, Skipped.
# Processing Record 36 of Set 2 | acapulco
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=acapulco
#
# Processing Record 37 of Set 2 | saint george
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=saint george
#
# Processing Record 38 of Set 2 | pisco
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=pisco
#
# Processing Record 39 of Set 2 | lompoc
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=lompoc
#
# Processing Record 40 of Set 2 | yellowknife
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=yellowknife
#
# Processing Record 41 of Set 2 | samusu
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=samusu
#
# City Not Found, Skipped.
# Processing Record 42 of Set 2 | anju
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=anju
#
# Processing Record 43 of Set 2 | mocuba
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=mocuba
#
# Processing Record 44 of Set 2 | thouars
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=thouars
#
# Processing Record 45 of Set 2 | upernavik
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=upernavik
#
# Processing Record 46 of Set 2 | the valley
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=the valley
#
# Processing Record 47 of Set 2 | jamestown
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=jamestown
#
# Processing Record 48 of Set 2 | kieta
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kieta
#
# Processing Record 49 of Set 2 | carnarvon
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=carnarvon
#
# Processing Record 0 of Set 3 | tuatapere
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tuatapere
#
# Processing Record 1 of Set 3 | bengkulu
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=bengkulu
#
# Processing Record 2 of Set 3 | amudat
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=amudat
#
# Processing Record 3 of Set 3 | ishigaki
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=ishigaki
# Processing Record 4 of Set 3 | avarua
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=avarua
#
# Processing Record 5 of Set 3 | nocera superiore
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=nocera superiore
#
# Processing Record 6 of Set 3 | alegrete
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=alegrete
#
# Processing Record 7 of Set 3 | challans
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=challans
#
# Processing Record 8 of Set 3 | talnakh
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=talnakh
#
# Processing Record 9 of Set 3 | lagoa
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=lagoa
#
# Processing Record 10 of Set 3 | kattivakkam
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kattivakkam
#
# Processing Record 11 of Set 3 | attawapiskat
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=attawapiskat
#
# City Not Found, Skipped.
# Processing Record 12 of Set 3 | kaitangata
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kaitangata
#
# Processing Record 13 of Set 3 | castro
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=castro
#
# Processing Record 14 of Set 3 | chuy
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=chuy
#
# Processing Record 15 of Set 3 | east london
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=east london
#
# Processing Record 16 of Set 3 | provideniya
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=provideniya
#
# Processing Record 17 of Set 3 | calabozo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=calabozo
#
# Processing Record 18 of Set 3 | mys shmidta
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=mys shmidta
#
# City Not Found, Skipped.
# Processing Record 19 of Set 3 | nuevitas
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=nuevitas
#
# Processing Record 20 of Set 3 | tasiilaq
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tasiilaq
#
# Processing Record 21 of Set 3 | cayenne
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=cayenne
#
# Processing Record 22 of Set 3 | paratinga
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=paratinga
#
# Processing Record 23 of Set 3 | cobija
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=cobija
#
# Processing Record 24 of Set 3 | ugoofaaru
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=ugoofaaru
#
# Processing Record 25 of Set 3 | kaeo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kaeo
#
# Processing Record 26 of Set 3 | flinders
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=flinders
#
# Processing Record 27 of Set 3 | lebu
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=lebu
#
# Processing Record 28 of Set 3 | belushya guba
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=belushya guba
#
# City Not Found, Skipped.
# Processing Record 29 of Set 3 | mar del plata
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=mar del plata
#
# Processing Record 30 of Set 3 | dabat
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=dabat
#
# Processing Record 31 of Set 3 | codrington
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=codrington
#
# Processing Record 32 of Set 3 | shanghai
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=shanghai
#
# Processing Record 33 of Set 3 | laguna
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=laguna
#
# Processing Record 34 of Set 3 | kirakira
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kirakira
#
# Processing Record 35 of Set 3 | sosnovo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=sosnovo
#
# Processing Record 36 of Set 3 | isiro
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=isiro
#
# Processing Record 37 of Set 3 | changzhou
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=changzhou
#
# Processing Record 38 of Set 3 | abeche
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=abeche
#
# Processing Record 39 of Set 3 | kimbe
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kimbe
#
# Processing Record 40 of Set 3 | marawi
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=marawi
#
# Processing Record 41 of Set 3 | tual
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tual
#
# Processing Record 42 of Set 3 | kemptville
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kemptville
#
# Processing Record 43 of Set 3 | bilma
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=bilma
#
# Processing Record 44 of Set 3 | arraial do cabo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=arraial do cabo
#
# Processing Record 45 of Set 3 | beni suef
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=beni suef
#
# Processing Record 46 of Set 3 | hamilton
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=hamilton
#
# Processing Record 47 of Set 3 | tuktoyaktuk
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tuktoyaktuk
#
# Processing Record 48 of Set 3 | kodiak
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kodiak
#
# Processing Record 49 of Set 3 | nipawin
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=nipawin
#
# Processing Record 0 of Set 4 | eureka
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=eureka
#
# Processing Record 1 of Set 4 | thompson
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=thompson
#
# Processing Record 2 of Set 4 | puerto ayora
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=puerto ayora
#
# Processing Record 3 of Set 4 | bone
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=bone
#
# Processing Record 4 of Set 4 | srednekolymsk
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=srednekolymsk
#
# Processing Record 5 of Set 4 | dwarka
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=dwarka
#
# Processing Record 6 of Set 4 | concepcion del uruguay
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=concepcion del uruguay
# Processing Record 7 of Set 4 | ketchikan
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=ketchikan
#
# Processing Record 8 of Set 4 | hermanus
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=hermanus
#
# Processing Record 9 of Set 4 | summerside
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=summerside
#
# Processing Record 10 of Set 4 | grindavik
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=grindavik
#
# Processing Record 11 of Set 4 | kerrobert
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kerrobert
#
# Processing Record 12 of Set 4 | coos bay
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=coos bay
#
# Processing Record 13 of Set 4 | port lincoln
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=port lincoln
#
# Processing Record 14 of Set 4 | zhanaozen
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=zhanaozen
#
# Processing Record 15 of Set 4 | julio de castilhos
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=julio de castilhos
#
# Processing Record 16 of Set 4 | half moon bay
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=half moon bay
#
# Processing Record 17 of Set 4 | magalia
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=magalia
#
# Processing Record 18 of Set 4 | grand river south east
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=grand river south east
#
# City Not Found, Skipped.
# Processing Record 19 of Set 4 | birin
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=birin
#
# Processing Record 20 of Set 4 | kavaratti
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kavaratti
#
# Processing Record 21 of Set 4 | saleaula
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=saleaula
#
# City Not Found, Skipped.
# Processing Record 22 of Set 4 | tabiauea
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tabiauea
#
# City Not Found, Skipped.
# Processing Record 23 of Set 4 | bredasdorp
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=bredasdorp
#
# Processing Record 24 of Set 4 | saskylakh
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=saskylakh
#
# Processing Record 25 of Set 4 | ribeira grande
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=ribeira grande
#
# Processing Record 26 of Set 4 | tomatlan
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tomatlan
#
# Processing Record 27 of Set 4 | bonga
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=bonga
#
# Processing Record 28 of Set 4 | karaul
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=karaul
#
# City Not Found, Skipped.
# Processing Record 29 of Set 4 | kilifi
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kilifi
#
# Processing Record 30 of Set 4 | ilulissat
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=ilulissat
#
# Processing Record 31 of Set 4 | kadnikov
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kadnikov
#
# Processing Record 32 of Set 4 | la ronge
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=la ronge
#
# Processing Record 33 of Set 4 | buchanan
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=buchanan
#
# Processing Record 34 of Set 4 | savinka
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=savinka
#
# Processing Record 35 of Set 4 | babanusah
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=babanusah
#
# City Not Found, Skipped.
# Processing Record 36 of Set 4 | omsukchan
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=omsukchan
#
# Processing Record 37 of Set 4 | kushmurun
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kushmurun
#
# Processing Record 38 of Set 4 | vestmannaeyjar
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=vestmannaeyjar
#
# Processing Record 39 of Set 4 | mahebourg
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=mahebourg
#
# Processing Record 40 of Set 4 | atambua
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=atambua
#
# Processing Record 41 of Set 4 | barentsburg
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=barentsburg
#
# City Not Found, Skipped.
# Processing Record 42 of Set 4 | port hedland
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=port hedland
#
# Processing Record 43 of Set 4 | salmas
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=salmas
#
# Processing Record 44 of Set 4 | san jose
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=san jose
#
# Processing Record 45 of Set 4 | edson
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=edson
#
# Processing Record 46 of Set 4 | warrington
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=warrington
#
# Processing Record 47 of Set 4 | burns lake
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=burns lake
#
# Processing Record 48 of Set 4 | port moresby
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=port moresby
#
# Processing Record 49 of Set 4 | thanh hoa
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=thanh hoa
#
# Processing Record 0 of Set 5 | olafsvik
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=olafsvik
#
# Processing Record 1 of Set 5 | tagusao
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tagusao
#
# Processing Record 2 of Set 5 | porto novo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=porto novo
#
# Processing Record 3 of Set 5 | kholodnyy
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kholodnyy
#
# Processing Record 4 of Set 5 | santa eulalia del rio
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=santa eulalia del rio
#
# City Not Found, Skipped.
# Processing Record 5 of Set 5 | tiksi
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tiksi
#
# Processing Record 6 of Set 5 | vila franca do campo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=vila franca do campo
#
# Processing Record 7 of Set 5 | cartagena
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=cartagena
# Processing Record 8 of Set 5 | eskasem
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=eskasem
#
# City Not Found, Skipped.
# Processing Record 9 of Set 5 | umzimvubu
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=umzimvubu
#
# City Not Found, Skipped.
# Processing Record 10 of Set 5 | port macquarie
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=port macquarie
#
# Processing Record 11 of Set 5 | zhicheng
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=zhicheng
#
# Processing Record 12 of Set 5 | alanya
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=alanya
#
# Processing Record 13 of Set 5 | korla
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=korla
#
# Processing Record 14 of Set 5 | nederland
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=nederland
#
# Processing Record 15 of Set 5 | brumado
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=brumado
#
# Processing Record 16 of Set 5 | fortuna
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=fortuna
#
# Processing Record 17 of Set 5 | arman
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=arman
#
# Processing Record 18 of Set 5 | brae
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=brae
#
# Processing Record 19 of Set 5 | general roca
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=general roca
#
# Processing Record 20 of Set 5 | sioux lookout
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=sioux lookout
#
# Processing Record 21 of Set 5 | aizkraukle
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=aizkraukle
#
# Processing Record 22 of Set 5 | tolaga bay
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tolaga bay
#
# Processing Record 23 of Set 5 | achisay
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=achisay
#
# City Not Found, Skipped.
# Processing Record 24 of Set 5 | stoyba
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=stoyba
#
# City Not Found, Skipped.
# Processing Record 25 of Set 5 | port alfred
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=port alfred
#
# Processing Record 26 of Set 5 | provo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=provo
#
# Processing Record 27 of Set 5 | dingle
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=dingle
#
# Processing Record 28 of Set 5 | shingu
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=shingu
#
# Processing Record 29 of Set 5 | waipawa
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=waipawa
#
# Processing Record 30 of Set 5 | coquimbo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=coquimbo
#
# Processing Record 31 of Set 5 | mount gambier
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=mount gambier
#
# Processing Record 32 of Set 5 | ylojarvi
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=ylojarvi
#
# Processing Record 33 of Set 5 | haines junction
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=haines junction
#
# Processing Record 34 of Set 5 | camopi
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=camopi
#
# Processing Record 35 of Set 5 | morgan city
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=morgan city
#
# Processing Record 36 of Set 5 | whitehorse
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=whitehorse
#
# Processing Record 37 of Set 5 | razvilnoye
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=razvilnoye
#
# Processing Record 38 of Set 5 | souillac
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=souillac
#
# Processing Record 39 of Set 5 | belyy yar
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=belyy yar
#
# Processing Record 40 of Set 5 | saint-francois
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=saint-francois
#
# Processing Record 41 of Set 5 | luderitz
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=luderitz
#
# Processing Record 42 of Set 5 | staryy nadym
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=staryy nadym
#
# Processing Record 43 of Set 5 | tumannyy
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tumannyy
#
# City Not Found, Skipped.
# Processing Record 44 of Set 5 | alta floresta
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=alta floresta
#
# Processing Record 45 of Set 5 | sao paulo de olivenca
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=sao paulo de olivenca
#
# Processing Record 46 of Set 5 | nizhniy kuranakh
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=nizhniy kuranakh
#
# Processing Record 47 of Set 5 | tacoronte
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tacoronte
#
# Processing Record 48 of Set 5 | baghdad
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=baghdad
#
# Processing Record 49 of Set 5 | ulladulla
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=ulladulla
#
# Processing Record 0 of Set 6 | cabo san lucas
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=cabo san lucas
#
# Processing Record 1 of Set 6 | ponta do sol
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=ponta do sol
#
# Processing Record 2 of Set 6 | esperance
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=esperance
#
# Processing Record 3 of Set 6 | san quintin
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=san quintin
#
# Processing Record 4 of Set 6 | svetlyy
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=svetlyy
#
# Processing Record 5 of Set 6 | dong hoi
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=dong hoi
#
# Processing Record 6 of Set 6 | grand gaube
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=grand gaube
#
# Processing Record 7 of Set 6 | svetlogorsk
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=svetlogorsk
#
# Processing Record 8 of Set 6 | ixtapa
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=ixtapa
# Processing Record 9 of Set 6 | hay river
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=hay river
#
# Processing Record 10 of Set 6 | olinda
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=olinda
#
# Processing Record 11 of Set 6 | los llanos de aridane
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=los llanos de aridane
#
# Processing Record 12 of Set 6 | kurilsk
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kurilsk
#
# Processing Record 13 of Set 6 | beidao
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=beidao
#
# Processing Record 14 of Set 6 | novikovo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=novikovo
#
# Processing Record 15 of Set 6 | corrales
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=corrales
#
# Processing Record 16 of Set 6 | qaqortoq
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=qaqortoq
#
# Processing Record 17 of Set 6 | broken hill
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=broken hill
#
# Processing Record 18 of Set 6 | yarkovo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=yarkovo
#
# Processing Record 19 of Set 6 | karaton
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=karaton
#
# Processing Record 20 of Set 6 | keningau
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=keningau
#
# Processing Record 21 of Set 6 | papar
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=papar
#
# Processing Record 22 of Set 6 | lucea
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=lucea
#
# Processing Record 23 of Set 6 | faanui
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=faanui
#
# Processing Record 24 of Set 6 | lamu
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=lamu
#
# Processing Record 25 of Set 6 | barcelos
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=barcelos
#
# Processing Record 26 of Set 6 | zhigansk
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=zhigansk
#
# Processing Record 27 of Set 6 | geraldton
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=geraldton
#
# Processing Record 28 of Set 6 | booue
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=booue
#
# Processing Record 29 of Set 6 | farah
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=farah
#
# Processing Record 30 of Set 6 | xam nua
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=xam nua
#
# Processing Record 31 of Set 6 | gemena
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=gemena
#
# Processing Record 32 of Set 6 | victoria
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=victoria
#
# Processing Record 33 of Set 6 | aksay
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=aksay
#
# Processing Record 34 of Set 6 | tsihombe
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tsihombe
#
# City Not Found, Skipped.
# Processing Record 35 of Set 6 | burayevo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=burayevo
#
# Processing Record 36 of Set 6 | ampanihy
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=ampanihy
#
# Processing Record 37 of Set 6 | tilichiki
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tilichiki
#
# Processing Record 38 of Set 6 | clyde river
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=clyde river
#
# Processing Record 39 of Set 6 | khatanga
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=khatanga
#
# Processing Record 40 of Set 6 | itarema
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=itarema
#
# Processing Record 41 of Set 6 | bela
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=bela
#
# Processing Record 42 of Set 6 | celano
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=celano
#
# Processing Record 43 of Set 6 | pierre
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=pierre
#
# Processing Record 44 of Set 6 | sur
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=sur
#
# Processing Record 45 of Set 6 | lerwick
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=lerwick
#
# Processing Record 46 of Set 6 | ambrolauri
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=ambrolauri
#
# Processing Record 47 of Set 6 | saldanha
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=saldanha
#
# Processing Record 48 of Set 6 | christchurch
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=christchurch
#
# Processing Record 49 of Set 6 | espanola
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=espanola
#
# Processing Record 0 of Set 7 | riohacha
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=riohacha
#
# Processing Record 1 of Set 7 | zhaotong
#
# ...
#
# Processing Record 8 of Set 11 | dalvik
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=dalvik
#
# Processing Record 9 of Set 11 | praia
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=praia
#
# Processing Record 10 of Set 11 | abu samrah
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=abu samrah
#
# Processing Record 11 of Set 11 | kanigiri
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kanigiri
#
# Processing Record 12 of Set 11 | roberto payan
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=roberto payan
#
# City Not Found, Skipped.
# Processing Record 13 of Set 11 | amursk
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=amursk
#
# Processing Record 14 of Set 11 | gizo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=gizo
#
# Processing Record 15 of Set 11 | kitimat
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kitimat
#
# Processing Record 16 of Set 11 | tazovskiy
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tazovskiy
#
# Processing Record 17 of Set 11 | sangar
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=sangar
#
# Processing Record 18 of Set 11 | maxixe
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=maxixe
#
# Processing Record 19 of Set 11 | kargasok
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kargasok
#
# Processing Record 20 of Set 11 | rocha
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=rocha
# Processing Record 21 of Set 11 | poum
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=poum
#
# Processing Record 22 of Set 11 | warwick
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=warwick
#
# Processing Record 23 of Set 11 | tukrah
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tukrah
#
# Processing Record 24 of Set 11 | chingola
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=chingola
#
# Processing Record 25 of Set 11 | baft
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=baft
#
# Processing Record 26 of Set 11 | nanortalik
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=nanortalik
#
# Processing Record 27 of Set 11 | lypnyazhka
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=lypnyazhka
#
# Processing Record 28 of Set 11 | tvoroyri
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tvoroyri
#
# Processing Record 29 of Set 11 | port blair
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=port blair
#
# Processing Record 30 of Set 11 | uromi
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=uromi
#
# Processing Record 31 of Set 11 | yerbogachen
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=yerbogachen
#
# Processing Record 32 of Set 11 | agadez
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=agadez
#
# Processing Record 33 of Set 11 | jiangyou
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=jiangyou
#
# Processing Record 34 of Set 11 | maceio
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=maceio
#
# Processing Record 35 of Set 11 | avanigadda
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=avanigadda
#
# Processing Record 36 of Set 11 | manjacaze
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=manjacaze
#
# Processing Record 37 of Set 11 | baruun-urt
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=baruun-urt
#
# Processing Record 38 of Set 11 | awjilah
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=awjilah
#
# Processing Record 39 of Set 11 | la grande
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=la grande
#
# Processing Record 40 of Set 11 | agropoli
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=agropoli
#
# Processing Record 41 of Set 11 | tankhoy
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tankhoy
#
# Processing Record 42 of Set 11 | bolitoc
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=bolitoc
#
# Processing Record 43 of Set 11 | kenai
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kenai
#
# Processing Record 44 of Set 11 | araouane
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=araouane
#
# Processing Record 45 of Set 11 | chumphon
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=chumphon
#
# Processing Record 46 of Set 11 | yar-sale
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=yar-sale
#
# Processing Record 47 of Set 11 | krini
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=krini
#
# Processing Record 48 of Set 11 | vanimo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=vanimo
#
# Processing Record 49 of Set 11 | stornoway
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=stornoway
#
# Processing Record 0 of Set 12 | xining
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=xining
#
# Processing Record 1 of Set 12 | inhambane
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=inhambane
#
# Processing Record 2 of Set 12 | crawfordsville
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=crawfordsville
#
# Processing Record 3 of Set 12 | clinton
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=clinton
#
# Processing Record 4 of Set 12 | fomboni
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=fomboni
#
# Processing Record 5 of Set 12 | moravska trebova
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=moravska trebova
#
# Processing Record 6 of Set 12 | vinh
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=vinh
#
# Processing Record 7 of Set 12 | mongoumba
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=mongoumba
#
# Processing Record 8 of Set 12 | lethem
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=lethem
#
# Processing Record 9 of Set 12 | saint-georges
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=saint-georges
#
# Processing Record 10 of Set 12 | svencionys
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=svencionys
#
# Processing Record 11 of Set 12 | bubaque
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=bubaque
#
# Processing Record 12 of Set 12 | batemans bay
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=batemans bay
#
# Processing Record 13 of Set 12 | ciudad bolivar
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=ciudad bolivar
#
# Processing Record 14 of Set 12 | sobolevo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=sobolevo
#
# Processing Record 15 of Set 12 | castletown
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=castletown
#
# Processing Record 16 of Set 12 | igarape-miri
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=igarape-miri
#
# City Not Found, Skipped.
# Processing Record 17 of Set 12 | mineros
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=mineros
#
# Processing Record 18 of Set 12 | matay
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=matay
#
# Processing Record 19 of Set 12 | beecher
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=beecher
#
# Processing Record 20 of Set 12 | bykovo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=bykovo
#
# Processing Record 21 of Set 12 | kaka
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=kaka
#
# Processing Record 22 of Set 12 | barra
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=barra
#
# Processing Record 23 of Set 12 | petropavlovsk-kamchatskiy
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=petropavlovsk-kamchatskiy
# Processing Record 24 of Set 12 | port-gentil
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=port-gentil
#
# Processing Record 25 of Set 12 | wagar
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=wagar
#
# Processing Record 26 of Set 12 | baculin
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=baculin
#
# Processing Record 27 of Set 12 | rapina
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=rapina
#
# Processing Record 28 of Set 12 | anaconda
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=anaconda
#
# Processing Record 29 of Set 12 | selikhino
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=selikhino
#
# Processing Record 30 of Set 12 | pokosnoye
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=pokosnoye
#
# Processing Record 31 of Set 12 | bilibino
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=bilibino
#
# Processing Record 32 of Set 12 | manavalakurichi
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=manavalakurichi
#
# Processing Record 33 of Set 12 | plettenberg bay
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=plettenberg bay
#
# Processing Record 34 of Set 12 | krasnomayskiy
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=krasnomayskiy
#
# Processing Record 35 of Set 12 | chagda
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=chagda
#
# City Not Found, Skipped.
# Processing Record 36 of Set 12 | mahibadhoo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=mahibadhoo
#
# Processing Record 37 of Set 12 | gobabis
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=gobabis
#
# Processing Record 38 of Set 12 | ancona
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=ancona
#
# Processing Record 39 of Set 12 | coahuayana
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=coahuayana
#
# Processing Record 40 of Set 12 | samarai
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=samarai
#
# Processing Record 41 of Set 12 | lima
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=lima
#
# Processing Record 42 of Set 12 | tignere
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=tignere
#
# Processing Record 43 of Set 12 | hobbs
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=hobbs
#
# Processing Record 44 of Set 12 | laksham
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=laksham
#
# Processing Record 45 of Set 12 | uporovo
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=uporovo
#
# Processing Record 46 of Set 12 | amuntai
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=amuntai
#
# Processing Record 47 of Set 12 | lata
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=lata
#
# Processing Record 48 of Set 12 | teano
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=teano
#
# Processing Record 49 of Set 12 | auki
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=auki
#
# Processing Record 0 of Set 13 | elko
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=elko
#
# Processing Record 1 of Set 13 | severnyy
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=severnyy
#
# Processing Record 2 of Set 13 | naze
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=naze
#
# Processing Record 3 of Set 13 | bolotnoye
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=bolotnoye
#
# Processing Record 4 of Set 13 | inveraray
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=inveraray
#
# City Not Found, Skipped.
# Processing Record 5 of Set 13 | oktyabrskiy
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=oktyabrskiy
#
# Processing Record 6 of Set 13 | sabla
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=sabla
#
# Processing Record 7 of Set 13 | jalu
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=jalu
#
# Processing Record 8 of Set 13 | amapa
#
# http://api.openweathermap.org/data/2.5/weather?appid=401db67f0e7558c6fcb2a9eae14075b9&units=imperial&q=amapa

# %%
#Check that data was captured properly
print(f"City:       {city_name}")
print(f"Cloudiness: {cloudiness}")
print(f"Country:    {country}")
print(f"Date:       {date}")
print(f"Humidity:   {humidity}")
print(f"Lat:        {lat}")
print(f"Lng:        {lng}")
print(f"Max Temp:   {max_temp}")
print(f"Wind Speed: {wind_speed}")
# Out:
# City:       ['Rikitea', 'Beringovskiy', 'Albany', 'La Tuque', 'Praia da Vitoria', 'Beloha', 'Hilo', 'Ushuaia', 'Republic of El Salvador', 'Vulturu', 'Glendive', 'Pangnirtung', 'Klaksvik', 'Ancud', 'Hithadhoo', 'Magnolia', 'Cape Town', 'Emerald', 'Bethel', 'Sept-Iles', 'Praxedis Guerrero', 'Sabang', 'Hornepayne', 'Mount Isa', 'Airai', 'Sao Filipe', 'Hobart', 'Edeia', 'Barrow', 'Kumul', 'Busselton', 'Tromso', 'Shenkursk', 'Boa Vista', 'Saint-Augustin', 'Katsuura', 'Nikolskoye', 'Torbay', 'Narsaq', 'Ucluelet', 'Sinegorye', 'Isangel', 'Tessalit', 'Nantucket', 'Dikson', 'Bluff', 'Kapaa', 'San Patricio', 'Kassala', 'Cidreira', 'Cherskiy', 'Tashla', 'Pontes e Lacerda', 'Atuona', 'Faya', 'New Norfolk', "Ust'-Kan", 'Steamboat Springs', 'George Town', 'Bambous Virieux', 'Butaritari', 'Punta Arenas', 'Kabalo', 'Huarmey', 'Mataura', 'Quatre Cocos', 'Kommunisticheskiy', 'Hasaki', 'Bariloche', 'Bourail', 'Saint-Philippe', 'Hualmay', 'Karla', 'College', 'Lavrentiya', 'Toyooka', 'Vila Praia de Ancora', 'Vaini', 'Norman Wells', 'Antofagasta', 'Port Elizabeth', 'Mehamn', 'Acapulco de Juarez', 'Saint George
 18.68, 4.63, 6.93, 8.05, 15.5, 4, 2.13, 14.65, 6.93, 13.87, 19.48, 11.14, 2.71, 3.36, 0.78, 6.87, 12.71, 5.01, 11.41, 4.7, 4.97, 3.85, 2.73, 1.54, 11.34, 4.32, 2.24, 6.76, 11.3, 16.87, 3.36, 17.43, 8.05, 5.55, 3.13, 13.87, 6.91, 1.97, 6.93, 5.73, 0.85, 7.49, 8.19, 1.01, 2.95, 2.48, 11.41, 16.42, 8.34, 6.91, 12.88, 16.11, 2.42, 9.71, 15.64, 1.54, 13.87, 1.99, 18.34, 23.02, 5.5, 19.46, 6.6, 16.6, 24.16, 13.87, 14.25, 7.99, 11.56, 6.87, 17.22, 13.49, 2.1, 7.76, 4, 18.32, 13.71, 8.61, 10.54, 4.7, 19.46, 10.31, 7.38, 3.36, 9.28, 2.48, 26.46, 2.68, 9.17, 13.53, 22.3, 14.92, 8.05, 13.11, 4.05, 7.05, 18.77, 6.4, 8.05, 11.56, 1.86, 4.43, 13.29, 1.7, 13.87, 6.76, 11.77, 1.28, 11.7, 3.36, 6.93, 2.75, 5.91, 9.17, 8.77, 2.48, 18.59, 2.82, 21.99, 9.17, 5.59, 9.17, 12.75, 13.87, 4.72, 18.34, 1.32, 0.78, 16.46, 18.34, 11.56, 10.18, 5.1, 12.33, 9.06, 18.34, 17.22, 13.13, 16.11, 4.47, 9.04, 5.59, 11.18, 5.82, 12.12, 5.26, 13.42, 7.74, 2.84, 1.9, 1.61, 2.24, 25.32, 10.58, 19.48, 11.05, 11.41, 1.19, 6.2, 8.05, 8.75, 25.28, 9.31, 14.29, 1.43, 18.34, 10.29, 17.43, 4.7, 6.71, 11.41, 14.12, 18.16, 9.37, 11.7, 5.84]

# %%
#Check that lengths are equal
print(len(city_name))
print(len(cloudiness))
print(len(country))
print(len(date))
print(len(humidity))
print(len(lat))
print(len(lng))
print(len(max_temp))
print(len(wind_speed))
# Out:
# 566
# 566
# 566
# 566
# 566
# 566
# 566
# 566
# 566

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Build a dataframe from the lists
weather_data = {"City": city_name, 
                "Cloudiness (%)": cloudiness, 
                "Country": country, 
                "Date": date, 
                "Humidity (%)": humidity, 
                "Lat": lat, 
                "Lng": lng, 
                "Max Temp (F)": max_temp, 
                "Wind Speed (mph)": wind_speed
}

weather_data = pd.DataFrame(weather_data)
weather_data.head()
# Out:
#                City  Cloudiness (%) Country        Date  Humidity (%)    Lat  \
# 0           Rikitea               0      PF  1582038691            81 -23.12
# 1      Beringovskiy              42      RU  1582038692            84  63.05
# 2            Albany              90      US  1582038663            85  42.60
# 3          La Tuque             100      CA  1582038694            85  47.43
# 4  Praia da Vitoria              75      PT  1582038695            62  38.73
#
#       Lng  Max Temp (F)  Wind Speed (mph)
# 0 -134.97         78.44             15.12
# 1  179.32         -9.54             18.63
# 2  -73.97         34.00              3.36
# 3  -72.78         12.42              9.91
# 4  -27.07         57.20              8.93

# %%
weather_data.to_csv(output_data_file, index = False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp (F)"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude vs. Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Latitude_vs_Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity (%)"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Latitude_vs_Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness (%)"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Latitude_vs_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed (mph)"], marker="o", )

# Incorporate the other graph properties
plt.title("Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Latitude_vs_WindSpeed.png")

# Show plot
plt.show()
